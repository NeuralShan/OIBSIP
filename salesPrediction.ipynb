# %%
import pandas

# %%
df = pandas.read_csv("/Users/shan/VSCodeProjects/Internship work/Data/Advertising.csv")

# %%
df.keys()
# Out:
# Index(['Unnamed: 0', 'TV', 'Radio', 'Newspaper', 'Sales'], dtype='object')

# %%
X = df[['TV', 'Radio', 'Newspaper']]
y = df['Sales']

# %%
from sklearn import linear_model
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %%
regr = linear_model.LinearRegression()
regr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
predictedSales = regr.predict(X_test).tolist()
expectedSales = y_test.tolist()

# %%
from sklearn.metrics import r2_score

r2_score(predictedSales, expectedSales)
# Out:
# 0.8931853716629967

# %%
tup = list(zip(expectedSales, predictedSales))
resultDf = pandas.DataFrame(tup, columns=['expectedSales', 'predictedSales'])
resultDf
# Out:
#     expectedSales  predictedSales
# 0             6.6       10.626565
# 1             9.7        7.905868
# 2            22.3       20.947922
# 3            22.1       20.108076
# 4             8.0       11.021395
# 5             4.8        4.074308
# 6            25.4       23.704876
# 7            13.2       12.219642
# 8            23.8       22.541151
# 9            11.9       11.207376
# 10           13.3       13.490958
# 11            7.0        7.879854
# 12           15.9       18.519176
# 13           12.6       12.378797
# 14           11.8       11.854278
# 15           12.6       12.849996
# 16           10.3        9.681520
# 17           17.6       18.313651
# 18           15.2       15.162302
# 19           14.2       13.888737
# 20           14.6       14.174217
# 21           10.6       12.473187
# 22            5.5        8.635462
# 23            9.5        7.744634
# 24           13.2       12.817338
# 25           10.8       11.754604
# ...
